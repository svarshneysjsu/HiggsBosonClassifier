# %% [markdown]
# # Random Forest for Higgs Boson Detection

# %% [markdown]
# ## Import packages

# %%
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.pipeline import PipelineModel, Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import (
    MulticlassClassificationEvaluator,
    BinaryClassificationEvaluator,
)
from pyspark.sql.functions import col, expr, broadcast
from pyspark.ml.functions import vector_to_array
from pyspark.sql import SparkSession
from pyspark import SparkContext
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# ## Create SparkContext and SparkSession

# %%
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/13 00:08:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
CLEAN_DATA_FOLDER = "clean_data"
MODELS_FOLDER = "models"
TRAIN = True
SCHEMA = [
    "signal",
    "lepton pT",
    "lepton eta",
    "lepton phi",
    "missing energy magnitude",
    "missing energy phi",
    "jet 1 pt",
    "jet 1 eta",
    "jet 1 phi",
    "jet 1 b-tag",
    "jet 2 pt",
    "jet 2 eta",
    "jet 2 phi",
    "jet 2 b-tag",
    "jet 3 pt",
    "jet 3 eta",
    "jet 3 phi",
    "jet 3 b-tag",
    "jet 4 pt",
    "jet 4 eta",
    "jet 4 phi",
    "jet 4 b-tag",
    "m_jj",
    "m_jjj",
    "m_lv",
    "m_jlv",
    "m_bb",
    "m_wbb",
    "m_wwbb",
]

# %% [markdown]
# ## Read Train CSV, transform and load to Dataframe

# %%
rdd = sc.textFile(os.path.join(CLEAN_DATA_FOLDER, "train.csv"))
rdd = rdd.map(
    lambda row: [
        int(float(v)) if i == 0 else float(v) for i, v in enumerate(row.split(","))
    ]
)
train_df = rdd.toDF(schema=SCHEMA)

# %% [markdown]
# ## Build Random Forest Model
#
# if TRAIN is True, this will train a Random Forest Pipeline Model using train csv
#
# if TRAIN is False, this will load a trained Random Forest Pipeline Model from `models`

# %%
model = None
if TRAIN:
    vector_assembler = VectorAssembler(
        inputCols=[c for c in SCHEMA if c != "signal"], outputCol="features"
    )
    classifier = RandomForestClassifier(featuresCol="features", labelCol="signal", numTrees=20, maxDepth=10)
    pipeline = Pipeline(stages=[vector_assembler, classifier])
    model = pipeline.fit(train_df)
    model.save(os.path.join(MODELS_FOLDER, "randomForest"))
else:
    model = PipelineModel.load(os.path.join(MODELS_FOLDER, "randomForest"))
# Out:
# 24/05/13 00:08:29 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/05/13 00:08:42 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 24/05/13 00:08:45 WARN PythonRunner: Detected deadlock while completing task 0.0 in stage 4 (TID 118): Attempting to kill Python Worker
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_24 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_24 to disk instead.
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_27 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_27 to disk instead.
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_22 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_28 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_25 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_22 to disk instead.
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_25 to disk instead.
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_28 to disk instead.
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_20 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_20 to disk instead.
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_23 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_23 to disk instead.
# 24/05/13 00:09:15 WARN MemoryStore: Not enough space to cache rdd_29_29 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:15 WARN BlockManager: Persisting block rdd_29_29 to disk instead.
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_22 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_24 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_23 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_25 in memory.
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_25 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_20 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_27 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_31 in memory.
# 24/05/13 00:09:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_30 in memory.
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_31 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:16 WARN BlockManager: Persisting block rdd_29_31 to disk instead.
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_30 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:16 WARN BlockManager: Persisting block rdd_29_30 to disk instead.
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_28 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_29 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_34 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:16 WARN BlockManager: Persisting block rdd_29_34 to disk instead.
# 24/05/13 00:09:16 WARN MemoryStore: Not enough space to cache rdd_29_35 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:16 WARN BlockManager: Persisting block rdd_29_35 to disk instead.
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_38 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:17 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_30 in memory.
# 24/05/13 00:09:17 WARN BlockManager: Persisting block rdd_29_38 to disk instead.
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_30 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_36 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:17 WARN BlockManager: Persisting block rdd_29_36 to disk instead.
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_32 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:17 WARN BlockManager: Persisting block rdd_29_32 to disk instead.
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_37 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:17 WARN BlockManager: Persisting block rdd_29_37 to disk instead.
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_31 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_33 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:17 WARN BlockManager: Persisting block rdd_29_33 to disk instead.
# 24/05/13 00:09:17 WARN MemoryStore: Not enough space to cache rdd_29_38 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_35 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_34 in memory.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_34 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_41 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_41 to disk instead.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_39 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_39 to disk instead.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_40 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_40 to disk instead.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_32 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_42 in memory.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_33 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_37 in memory.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_37 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_42 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_42 to disk instead.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_39 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_36 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_40 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_47 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_47 to disk instead.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_48 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_48 to disk instead.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_46 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_46 to disk instead.
# 24/05/13 00:09:18 WARN MemoryStore: Not enough space to cache rdd_29_43 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:18 WARN BlockManager: Persisting block rdd_29_43 to disk instead.
# 24/05/13 00:09:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_50 in memory.
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_45 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:19 WARN BlockManager: Persisting block rdd_29_45 to disk instead.
# 24/05/13 00:09:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_41 in memory.
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_41 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_42 in memory.
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_42 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_50 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:19 WARN BlockManager: Persisting block rdd_29_50 to disk instead.
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_49 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:19 WARN BlockManager: Persisting block rdd_29_49 to disk instead.
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_44 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:19 WARN BlockManager: Persisting block rdd_29_44 to disk instead.
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_43 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_44 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:19 WARN MemoryStore: Not enough space to cache rdd_29_51 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:19 WARN BlockManager: Persisting block rdd_29_51 to disk instead.
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_46 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_49 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_47 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_53 in memory.
# 24/05/13 00:09:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_48 in memory.
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_48 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_53 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:20 WARN BlockManager: Persisting block rdd_29_53 to disk instead.
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_52 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:20 WARN BlockManager: Persisting block rdd_29_52 to disk instead.
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_45 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_50 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_56 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:20 WARN BlockManager: Persisting block rdd_29_56 to disk instead.
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_58 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:20 WARN BlockManager: Persisting block rdd_29_58 to disk instead.
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_55 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:20 WARN BlockManager: Persisting block rdd_29_55 to disk instead.
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_51 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:20 WARN MemoryStore: Not enough space to cache rdd_29_59 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:20 WARN BlockManager: Persisting block rdd_29_59 to disk instead.
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_54 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:21 WARN BlockManager: Persisting block rdd_29_54 to disk instead.
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_52 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_57 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:21 WARN BlockManager: Persisting block rdd_29_57 to disk instead.
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_54 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_53 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_60 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:21 WARN BlockManager: Persisting block rdd_29_60 to disk instead.
# 24/05/13 00:09:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_55 in memory.
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_55 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_61 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:21 WARN BlockManager: Persisting block rdd_29_61 to disk instead.
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_63 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:21 WARN BlockManager: Persisting block rdd_29_63 to disk instead.
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_56 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_58 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:21 WARN MemoryStore: Not enough space to cache rdd_29_57 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_59 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_68 in memory.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_68 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:22 WARN BlockManager: Persisting block rdd_29_68 to disk instead.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_65 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:22 WARN BlockManager: Persisting block rdd_29_65 to disk instead.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_64 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:22 WARN BlockManager: Persisting block rdd_29_64 to disk instead.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_67 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:22 WARN BlockManager: Persisting block rdd_29_67 to disk instead.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_60 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_66 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:22 WARN BlockManager: Persisting block rdd_29_66 to disk instead.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_62 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:22 WARN BlockManager: Persisting block rdd_29_62 to disk instead.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_61 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_63 in memory.
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_63 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:22 WARN MemoryStore: Not enough space to cache rdd_29_70 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:22 WARN BlockManager: Persisting block rdd_29_70 to disk instead.
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_62 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_69 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:23 WARN BlockManager: Persisting block rdd_29_69 to disk instead.
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_64 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:23 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_71 in memory.
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_71 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:23 WARN BlockManager: Persisting block rdd_29_71 to disk instead.
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_68 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_65 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:23 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_73 in memory.
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_72 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:23 WARN BlockManager: Persisting block rdd_29_72 to disk instead.
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_66 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_73 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:23 WARN BlockManager: Persisting block rdd_29_73 to disk instead.
# 24/05/13 00:09:23 WARN MemoryStore: Not enough space to cache rdd_29_67 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_77 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:24 WARN BlockManager: Persisting block rdd_29_77 to disk instead.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_70 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_74 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:24 WARN BlockManager: Persisting block rdd_29_74 to disk instead.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_69 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_78 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:24 WARN BlockManager: Persisting block rdd_29_78 to disk instead.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_75 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:24 WARN BlockManager: Persisting block rdd_29_75 to disk instead.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_71 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_72 in memory.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_72 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_73 in memory.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_73 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_76 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:24 WARN BlockManager: Persisting block rdd_29_76 to disk instead.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_79 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:24 WARN BlockManager: Persisting block rdd_29_79 to disk instead.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_76 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_80 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:24 WARN BlockManager: Persisting block rdd_29_80 to disk instead.
# 24/05/13 00:09:24 WARN MemoryStore: Not enough space to cache rdd_29_75 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_84 in memory.
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_78 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_82 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:25 WARN BlockManager: Persisting block rdd_29_82 to disk instead.
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_81 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:25 WARN BlockManager: Persisting block rdd_29_81 to disk instead.
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_77 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_74 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_84 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:25 WARN BlockManager: Persisting block rdd_29_84 to disk instead.
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_79 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_86 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:25 WARN BlockManager: Persisting block rdd_29_86 to disk instead.
# 24/05/13 00:09:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_80 in memory.
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_80 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:25 WARN MemoryStore: Not enough space to cache rdd_29_83 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:25 WARN BlockManager: Persisting block rdd_29_83 to disk instead.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_88 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:26 WARN BlockManager: Persisting block rdd_29_88 to disk instead.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_85 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:26 WARN BlockManager: Persisting block rdd_29_85 to disk instead.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_87 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:26 WARN BlockManager: Persisting block rdd_29_87 to disk instead.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_83 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_82 in memory.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_82 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_81 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_84 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_92 in memory.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_85 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_92 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:26 WARN BlockManager: Persisting block rdd_29_92 to disk instead.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_89 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:26 WARN BlockManager: Persisting block rdd_29_89 to disk instead.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_91 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:26 WARN BlockManager: Persisting block rdd_29_91 to disk instead.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_87 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_94 in memory.
# 24/05/13 00:09:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_86 in memory.
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_86 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:26 WARN MemoryStore: Not enough space to cache rdd_29_94 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:26 WARN BlockManager: Persisting block rdd_29_94 to disk instead.
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_89 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_95 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:27 WARN BlockManager: Persisting block rdd_29_95 to disk instead.
# 24/05/13 00:09:27 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_96 in memory.
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_93 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:27 WARN BlockManager: Persisting block rdd_29_93 to disk instead.
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_96 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:27 WARN BlockManager: Persisting block rdd_29_96 to disk instead.
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_90 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:27 WARN BlockManager: Persisting block rdd_29_90 to disk instead.
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_88 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_97 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:27 WARN BlockManager: Persisting block rdd_29_97 to disk instead.
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_90 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_93 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:27 WARN MemoryStore: Not enough space to cache rdd_29_98 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:27 WARN BlockManager: Persisting block rdd_29_98 to disk instead.
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_99 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:28 WARN BlockManager: Persisting block rdd_29_99 to disk instead.
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_91 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_94 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_92 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_95 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_100 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:28 WARN BlockManager: Persisting block rdd_29_100 to disk instead.
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_97 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_96 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_104 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:28 WARN BlockManager: Persisting block rdd_29_104 to disk instead.
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_101 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:28 WARN BlockManager: Persisting block rdd_29_101 to disk instead.
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_102 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:28 WARN BlockManager: Persisting block rdd_29_102 to disk instead.
# 24/05/13 00:09:28 WARN MemoryStore: Not enough space to cache rdd_29_103 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:28 WARN BlockManager: Persisting block rdd_29_103 to disk instead.
# 24/05/13 00:09:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_99 in memory.
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_99 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_98 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_107 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_101 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:29 WARN BlockManager: Persisting block rdd_29_107 to disk instead.
# 24/05/13 00:09:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_108 in memory.
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_100 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_108 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:29 WARN BlockManager: Persisting block rdd_29_108 to disk instead.
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_105 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:29 WARN BlockManager: Persisting block rdd_29_105 to disk instead.
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_106 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:29 WARN BlockManager: Persisting block rdd_29_106 to disk instead.
# 24/05/13 00:09:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_109 in memory.
# 24/05/13 00:09:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_110 in memory.
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_103 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_109 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:29 WARN BlockManager: Persisting block rdd_29_109 to disk instead.
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_110 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:29 WARN BlockManager: Persisting block rdd_29_110 to disk instead.
# 24/05/13 00:09:29 WARN MemoryStore: Not enough space to cache rdd_29_106 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_111 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:30 WARN BlockManager: Persisting block rdd_29_111 to disk instead.
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_102 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_105 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_107 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_104 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_114 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:30 WARN BlockManager: Persisting block rdd_29_114 to disk instead.
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_108 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_112 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:30 WARN BlockManager: Persisting block rdd_29_112 to disk instead.
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_115 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:30 WARN BlockManager: Persisting block rdd_29_115 to disk instead.
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_109 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_111 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:30 WARN MemoryStore: Not enough space to cache rdd_29_110 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:31 WARN MemoryStore: Not enough space to cache rdd_29_112 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:31 WARN MemoryStore: Not enough space to cache rdd_29_115 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:31 WARN MemoryStore: Not enough space to cache rdd_29_114 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:31 WARN MemoryStore: Not enough space to cache rdd_29_113 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:31 WARN BlockManager: Persisting block rdd_29_113 to disk instead.
# 24/05/13 00:09:31 WARN MemoryStore: Not enough space to cache rdd_29_113 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_23 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_20 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_22 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_27 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_24 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_28 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_28 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_25 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_29 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_30 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_30 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_31 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_34 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_32 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_36 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_35 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_37 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_33 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_38 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_39 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_42 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_43 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_43 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_40 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_41 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_45 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_45 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_44 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_47 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_47 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_48 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_48 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_46 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_49 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_51 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_51 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_53 in memory.
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_53 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_50 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_54 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_52 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_57 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_55 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_58 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_56 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:32 WARN MemoryStore: Not enough space to cache rdd_29_59 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_60 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_62 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_63 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_64 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_61 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_67 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_67 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_65 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_68 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_66 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_70 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_70 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_69 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_71 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_72 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_73 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_77 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_77 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_74 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_75 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_78 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_78 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_76 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_82 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_86 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_86 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_85 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_85 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_81 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_79 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_80 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_84 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_83 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_87 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_88 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_91 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_91 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_89 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_92 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_92 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_93 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_90 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_94 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_95 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_96 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_97 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_98 in memory.
# 24/05/13 00:09:33 WARN MemoryStore: Not enough space to cache rdd_29_98 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_102 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_99 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_104 in memory.
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_104 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_103 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_101 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_100 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_106 in memory.
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_106 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_105 in memory.
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_105 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_107 in memory.
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_107 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_108 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_110 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_109 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_113 in memory.
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_113 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_111 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_112 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_115 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:34 WARN MemoryStore: Not enough space to cache rdd_29_114 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_22 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_23 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_25 in memory.
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_25 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_27 in memory.
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_27 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_24 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_20 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_28 in memory.
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_28 in memory! (computed 384.0 B so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_29 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_30 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_31 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_33 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:09:35 WARN MemoryStore: Not enough space to cache rdd_29_32 in memory! (computed 5.7 MiB so far)
# ...
# 24/05/13 00:10:08 WARN MemoryStore: Not enough space to cache rdd_29_92 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:08 WARN MemoryStore: Not enough space to cache rdd_29_94 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_100 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_97 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_99 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_101 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_98 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_104 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_103 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:09 WARN MemoryStore: Not enough space to cache rdd_29_102 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:10 WARN MemoryStore: Not enough space to cache rdd_29_107 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:10 WARN MemoryStore: Not enough space to cache rdd_29_109 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:10 WARN MemoryStore: Not enough space to cache rdd_29_111 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:10 WARN MemoryStore: Not enough space to cache rdd_29_112 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:11 WARN MemoryStore: Not enough space to cache rdd_29_113 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:11 WARN MemoryStore: Not enough space to cache rdd_29_114 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:12 WARN DAGScheduler: Broadcasting large task binary with size 1625.6 KiB
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_1 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_4 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_8 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_0 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_9 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_6 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_7 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_2 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_3 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:12 WARN MemoryStore: Not enough space to cache rdd_29_5 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_13 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_11 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_14 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_12 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_15 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_16 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_10 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_17 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_18 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:13 WARN MemoryStore: Not enough space to cache rdd_29_19 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:14 WARN MemoryStore: Not enough space to cache rdd_29_24 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:15 WARN MemoryStore: Not enough space to cache rdd_29_26 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:15 WARN MemoryStore: Not enough space to cache rdd_29_27 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:15 WARN MemoryStore: Not enough space to cache rdd_29_29 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:15 WARN MemoryStore: Not enough space to cache rdd_29_28 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_34 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_31 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_32 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_35 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_33 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_36 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_37 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_38 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:16 WARN MemoryStore: Not enough space to cache rdd_29_39 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:17 WARN MemoryStore: Not enough space to cache rdd_29_42 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:17 WARN MemoryStore: Not enough space to cache rdd_29_44 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:17 WARN MemoryStore: Not enough space to cache rdd_29_46 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:17 WARN MemoryStore: Not enough space to cache rdd_29_47 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:17 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_48 in memory.
# 24/05/13 00:10:17 WARN MemoryStore: Not enough space to cache rdd_29_48 in memory! (computed 384.0 B so far)
# 24/05/13 00:10:18 WARN MemoryStore: Not enough space to cache rdd_29_50 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:18 WARN MemoryStore: Not enough space to cache rdd_29_51 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:19 WARN MemoryStore: Not enough space to cache rdd_29_56 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:19 WARN MemoryStore: Not enough space to cache rdd_29_57 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:10:19 WARN MemoryStore: Not enough space to cache rdd_29_55 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:19 WARN MemoryStore: Not enough space to cache rdd_29_58 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:10:19 WARN MemoryStore: Not enough space to cache rdd_29_53 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:19 WARN MemoryStore: Not enough space to cache rdd_29_54 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:19 WARN MemoryStore: Not enough space to cache rdd_29_59 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_64 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_63 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_61 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_62 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_65 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_66 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_68 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:10:20 WARN MemoryStore: Not enough space to cache rdd_29_67 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_70 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_71 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_77 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_75 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_74 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_73 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_76 in memory! (computed 1553.7 KiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_79 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:21 WARN MemoryStore: Not enough space to cache rdd_29_78 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:22 WARN MemoryStore: Not enough space to cache rdd_29_80 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:22 WARN MemoryStore: Not enough space to cache rdd_29_81 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:22 WARN MemoryStore: Not enough space to cache rdd_29_83 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:22 WARN MemoryStore: Not enough space to cache rdd_29_84 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:22 WARN MemoryStore: Not enough space to cache rdd_29_87 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:22 WARN MemoryStore: Not enough space to cache rdd_29_82 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:22 WARN MemoryStore: Not enough space to cache rdd_29_86 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:23 WARN MemoryStore: Not enough space to cache rdd_29_85 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_92 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_93 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_91 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_94 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_95 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_96 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_97 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:24 WARN MemoryStore: Not enough space to cache rdd_29_98 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:25 WARN MemoryStore: Not enough space to cache rdd_29_104 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:25 WARN MemoryStore: Not enough space to cache rdd_29_103 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:25 WARN MemoryStore: Not enough space to cache rdd_29_105 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:25 WARN MemoryStore: Not enough space to cache rdd_29_106 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:25 WARN MemoryStore: Not enough space to cache rdd_29_108 in memory! (computed 2.5 MiB so far)
# 24/05/13 00:10:26 WARN MemoryStore: Not enough space to cache rdd_29_109 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:26 WARN MemoryStore: Not enough space to cache rdd_29_112 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:26 WARN MemoryStore: Not enough space to cache rdd_29_111 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:26 WARN MemoryStore: Not enough space to cache rdd_29_110 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:26 WARN MemoryStore: Not enough space to cache rdd_29_113 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:28 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_4 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_8 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_7 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_0 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_3 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_5 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_2 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_9 in memory! (computed 3.8 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_6 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:29 WARN MemoryStore: Not enough space to cache rdd_29_1 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:33 WARN MemoryStore: Not enough space to cache rdd_29_22 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:33 WARN MemoryStore: Not enough space to cache rdd_29_21 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:33 WARN MemoryStore: Not enough space to cache rdd_29_20 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:33 WARN MemoryStore: Not enough space to cache rdd_29_25 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:33 WARN MemoryStore: Not enough space to cache rdd_29_24 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:33 WARN MemoryStore: Not enough space to cache rdd_29_23 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:35 WARN MemoryStore: Not enough space to cache rdd_29_33 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:35 WARN MemoryStore: Not enough space to cache rdd_29_35 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:35 WARN MemoryStore: Not enough space to cache rdd_29_34 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:39 WARN MemoryStore: Not enough space to cache rdd_29_50 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:39 WARN MemoryStore: Not enough space to cache rdd_29_51 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:41 WARN MemoryStore: Not enough space to cache rdd_29_60 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:41 WARN MemoryStore: Not enough space to cache rdd_29_61 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:41 WARN MemoryStore: Not enough space to cache rdd_29_62 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:43 WARN MemoryStore: Not enough space to cache rdd_29_71 in memory! (computed 1031.3 KiB so far)
# 24/05/13 00:10:45 WARN MemoryStore: Not enough space to cache rdd_29_80 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:45 WARN MemoryStore: Not enough space to cache rdd_29_82 in memory! (computed 5.7 MiB so far)
# 24/05/13 00:10:45 WARN MemoryStore: Not enough space to cache rdd_29_83 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:47 WARN MemoryStore: Not enough space to cache rdd_29_92 in memory! (computed 12.8 MiB so far)
# 24/05/13 00:10:47 WARN MemoryStore: Not enough space to cache rdd_29_93 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:49 WARN MemoryStore: Not enough space to cache rdd_29_99 in memory! (computed 20.3 MiB so far)
# 24/05/13 00:10:49 WARN MemoryStore: Not enough space to cache rdd_29_101 in memory! (computed 8.5 MiB so far)
# 24/05/13 00:10:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_29_102 in memory.
# 24/05/13 00:10:49 WARN MemoryStore: Not enough space to cache rdd_29_102 in memory! (computed 384.0 B so far)
# 24/05/13 00:10:51 WARN MemoryStore: Not enough space to cache rdd_29_110 in memory! (computed 1031.3 KiB so far)

# %% [markdown]
# ## Feature Importance

# %%
importances = model.stages[-1].featureImportances.toArray()
feature_names = model.stages[0].getInputCols()
feature_importances = list(zip(feature_names, importances))
feature_importances = sorted(feature_importances, key=lambda x: x[1], reverse=True)
feature_names, importances = zip(*feature_importances)
_, ax = plt.subplots(1, 1, figsize=(8, 6))
_ = sns.barplot(x=importances, y=feature_names, ax=ax)
ax.set_title("Feature Importance")
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %% [markdown]
# ## Build Binary Classification Evaluators and Visualizers

# %%
evaluators = {
    "accuracy": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="accuracy"
    ),
    "precision": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="weightedPrecision"
    ),
    "recall": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="weightedRecall"
    ),
    "f1": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="f1"
    ),
    "areaUnderROC": BinaryClassificationEvaluator(
        labelCol="signal", rawPredictionCol="rawPrediction", metricName="areaUnderROC"
    ),
    "areaUnderPR": BinaryClassificationEvaluator(
        labelCol="signal", rawPredictionCol="rawPrediction", metricName="areaUnderPR"
    ),
}
metrics = []

# %%
def evaluate(predictions, split):
    accuracy = evaluators["accuracy"].evaluate(predictions)
    precision = evaluators["precision"].evaluate(predictions)
    recall = evaluators["recall"].evaluate(predictions)
    f1 = evaluators["f1"].evaluate(predictions)
    auc_roc = evaluators["areaUnderROC"].evaluate(predictions)
    auc_pr = evaluators["areaUnderPR"].evaluate(predictions)
    return {
        "Split": split,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "AreaUnderROC": auc_roc,
        "AreaUnderPR": auc_pr,
    }

# %%
def plot_confusion_matrix(predictions, split, ax):
    TP = predictions.filter(
        (predictions.prediction == 1) & (predictions.signal == 1)
    ).count()
    TN = predictions.filter(
        (predictions.prediction == 0) & (predictions.signal == 0)
    ).count()
    FP = predictions.filter(
        (predictions.prediction == 1) & (predictions.signal == 0)
    ).count()
    FN = predictions.filter(
        (predictions.prediction == 0) & (predictions.signal == 1)
    ).count()
    confusion_matrix = [[TP, FP], [FN, TN]]
    _ = sns.heatmap(
        confusion_matrix,
        annot=True,
        fmt="d",
        cmap="Blues",
        square=True,
        cbar=False,
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix for {split}")
    ax.set_ylabel("True Label")
    ax.set_xlabel("Predicted Label")

# %%
def plot_precision_recall_curve(predictions, split, ax):
    slim_preds = predictions.select(["signal", "probability", "prediction"]).withColumn(
        "probability_array", vector_to_array("probability")
    )
    # Create a DataFrame of threshold values
    thresholds = np.linspace(0, 1, num=100)
    threshold_df = spark.createDataFrame(
        [(float(t),) for t in thresholds], ["threshold"]
    )
    cross_joined = slim_preds.crossJoin(broadcast(threshold_df))
    # Define the conditions for TP, FP, TN, FN
    metrics_df = (
        cross_joined.withColumn(
            "Metric",
            expr(
                "CASE "
                + " WHEN probability_array[1] >= threshold AND signal = 1 THEN 'TP' "
                + " WHEN probability_array[1] >= threshold AND signal = 0 THEN 'FP' "
                + " WHEN probability_array[1] < threshold AND signal = 1 THEN 'FN' "
                + " ELSE 'TN' END"
            ),
        )
        .groupBy("threshold")
        .pivot("Metric")
        .count()
    )
    # Calculate precision and recall
    result_df = metrics_df.withColumn(
        "Precision", col("TP") / (col("TP") + col("FP"))
    ).withColumn("Recall", col("TP") / (col("TP") + col("FN")))
    # Collect results for plotting if necessary
    result_data = (
        result_df.select("threshold", "Precision", "Recall")
        .orderBy("threshold")
        .collect()
    )
    # Plotting
    precisions = [
        row["Precision"] for row in result_data if row["Precision"] is not None
    ]
    recalls = [row["Recall"] for row in result_data if row["Recall"] is not None]
    # Filter out None values and ensure that both precision and recall are present
    filtered_data = [
        (row["Precision"], row["Recall"])
        for row in result_data
        if row["Precision"] is not None and row["Recall"] is not None
    ]
    # x[1] is the recall
    sorted_data = sorted(filtered_data, key=lambda x: x[1])
    # Unpack the sorted data
    precisions, recalls = zip(*sorted_data)
    average_precision = 0.0
    for i in range(1, len(precisions)):
        average_precision += (recalls[i] - recalls[i - 1]) * precisions[i]
    # Plotting
    ax.plot(recalls, precisions, color="tab:blue", alpha=0.7)
    ax.fill_between(recalls, precisions, color="tab:blue", alpha=0.2)
    ax.set_title(f"Precision-Recall Curve for {split} (AP={average_precision:.4f})")
    ax.set_ylabel("Precision")
    ax.set_xlabel("Recall")
    ax.set_ylim([0.0, 1.0])
    ax.set_xlim([0.0, 1.0])

# %%
def plot_roc_curve(predictions, split, ax):
    slim_preds = predictions.select(["signal", "probability", "prediction"]).withColumn(
        "probability_array", vector_to_array("probability")
    )
    # Create a DataFrame of threshold values
    thresholds = np.linspace(0, 1, num=100)
    threshold_df = spark.createDataFrame(
        [(float(t),) for t in thresholds], ["threshold"]
    )
    cross_joined = slim_preds.crossJoin(broadcast(threshold_df))
    # Define the conditions for TP, FP, TN, FN
    metrics_df = (
        cross_joined.withColumn(
            "Metric",
            expr(
                "CASE "
                + " WHEN probability_array[1] >= threshold AND signal = 1 THEN 'TP' "
                + " WHEN probability_array[1] >= threshold AND signal = 0 THEN 'FP' "
                + " WHEN probability_array[1] < threshold AND signal = 1 THEN 'FN' "
                + " ELSE 'TN' END"
            ),
        )
        .groupBy("threshold")
        .pivot("Metric")
        .count()
    )
    metrics_summed = metrics_df.groupBy("threshold").sum("TP", "FP", "TN", "FN")
    # Calculate TPR and FPR
    result_df = metrics_summed.withColumn(
        "FPR", col("sum(FP)") / (col("sum(FP)") + col("sum(TN)"))
    ).withColumn("TPR", col("sum(TP)") / (col("sum(TP)") + col("sum(FN)")))
    # Collect results to the driver
    result_data = (
        result_df.select("threshold", "FPR", "TPR").orderBy("threshold").collect()
    )
    # Filter out None values from the results
    filtered_data = [
        row for row in result_data if row["FPR"] is not None and row["TPR"] is not None
    ]
    # Sort by FPR
    sorted_data = sorted(filtered_data, key=lambda x: x["FPR"])
    fprs = [row["FPR"] for row in sorted_data]
    tprs = [row["TPR"] for row in sorted_data]
    # Calculate AUC using the trapezoidal rule
    roc_auc = np.trapz(tprs, fprs)
    # Plotting
    ax.plot(
        fprs, tprs, color="tab:orange", lw=2, label=f"ROC Curve (Area={roc_auc:.4f})"
    )
    ax.plot([0, 1], [0, 1], color="tab:blue", lw=2, linestyle="--")
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")
    ax.set_title(f"Receiver Operating Characteristic for {split}")
    ax.legend(loc="lower right")
    ax.set_ylim([0.0, 1.0])
    ax.set_xlim([0.0, 1.0])

# %% [markdown]
# ## Predictions and Metrics for Train split

# %%
train_predictions = model.transform(train_df)

# %%
metrics.append(evaluate(predictions=train_predictions, split="Train"))
# Out:
# 24/05/13 00:10:56 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:11:15 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:12:11 WARN DAGScheduler: Broadcasting large task binary with size 1826.3 KiB
# 24/05/13 00:12:40 WARN DAGScheduler: Broadcasting large task binary with size 1826.3 KiB

# %%
# fig, ax = plt.subplots(1, 1, figsize=(8, 6))
# plot_confusion_matrix(train_predictions, "Train", ax)

# %%
# fig, ax = plt.subplots(1, 1, figsize=(6, 6))
# plot_roc_curve(train_predictions, "Train", ax)

# %%
# fig, ax = plt.subplots(1, 1, figsize=(6, 6))
# plot_precision_recall_curve(train_predictions, "Train", ax)

# %% [markdown]
# ## Read Test CSV, transform and load to Dataframe

# %%
rdd = sc.textFile(os.path.join(CLEAN_DATA_FOLDER, "test.csv"))
rdd = rdd.map(
    lambda row: [
        int(float(v)) if i == 0 else float(v) for i, v in enumerate(row.split(","))
    ]
)
test_df = rdd.toDF(schema=SCHEMA)

# %% [markdown]
# ## Predictions and Metrics for Test split

# %%
test_predictions = model.transform(test_df)

# %%
metrics.append(evaluate(predictions=test_predictions, split="Test"))
# Out:
# 24/05/13 00:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:13:20 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:13:28 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:13:36 WARN DAGScheduler: Broadcasting large task binary with size 1838.7 KiB
# 24/05/13 00:13:44 WARN DAGScheduler: Broadcasting large task binary with size 1826.3 KiB
# 24/05/13 00:13:57 WARN DAGScheduler: Broadcasting large task binary with size 1826.3 KiB

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
plot_confusion_matrix(test_predictions, "Test", ax)
# Out:
# 24/05/13 00:14:09 WARN DAGScheduler: Broadcasting large task binary with size 1814.0 KiB
# 24/05/13 00:14:18 WARN DAGScheduler: Broadcasting large task binary with size 1814.0 KiB
# 24/05/13 00:14:26 WARN DAGScheduler: Broadcasting large task binary with size 1814.0 KiB
# 24/05/13 00:14:34 WARN DAGScheduler: Broadcasting large task binary with size 1814.0 KiB

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
plot_roc_curve(test_predictions, "Test", ax)
# Out:
# 24/05/13 00:14:43 WARN DAGScheduler: Broadcasting large task binary with size 1847.5 KiB
# 24/05/13 00:16:32 WARN DAGScheduler: Broadcasting large task binary with size 1833.4 KiB
# 24/05/13 00:16:32 WARN DAGScheduler: Broadcasting large task binary with size 1833.6 KiB
# 24/05/13 00:16:32 WARN DAGScheduler: Broadcasting large task binary with size 1828.3 KiB
# 24/05/13 00:16:33 WARN DAGScheduler: Broadcasting large task binary with size 1851.6 KiB
# 24/05/13 00:18:26 WARN DAGScheduler: Broadcasting large task binary with size 1834.9 KiB
# 24/05/13 00:18:26 WARN DAGScheduler: Broadcasting large task binary with size 1881.9 KiB
# 24/05/13 00:18:26 WARN DAGScheduler: Broadcasting large task binary with size 1885.2 KiB
# 24/05/13 00:18:26 WARN DAGScheduler: Broadcasting large task binary with size 1856.9 KiB

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
plot_precision_recall_curve(test_predictions, "Test", ax)
# Out:
# 24/05/13 00:18:26 WARN DAGScheduler: Broadcasting large task binary with size 1847.5 KiB
# 24/05/13 00:20:17 WARN DAGScheduler: Broadcasting large task binary with size 1833.4 KiB
# 24/05/13 00:20:17 WARN DAGScheduler: Broadcasting large task binary with size 1833.6 KiB
# 24/05/13 00:20:17 WARN DAGScheduler: Broadcasting large task binary with size 1828.3 KiB
# 24/05/13 00:20:18 WARN DAGScheduler: Broadcasting large task binary with size 1851.6 KiB
# 24/05/13 00:22:10 WARN DAGScheduler: Broadcasting large task binary with size 1834.9 KiB
# 24/05/13 00:22:10 WARN DAGScheduler: Broadcasting large task binary with size 1841.9 KiB
# 24/05/13 00:22:10 WARN DAGScheduler: Broadcasting large task binary with size 1845.1 KiB
# 24/05/13 00:22:10 WARN DAGScheduler: Broadcasting large task binary with size 1844.6 KiB

# %% [markdown]
# ## Print Metrics

# %%
spark.createDataFrame(metrics).show(truncate=False)
# Out:
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+
# |Accuracy          |AreaUnderPR       |AreaUnderROC      |F1                |Precision         |Recall            |Split|
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+
# |0.7083637113692373|0.7950372912373052|0.7810035121184349|0.7078322039825453|0.7079955239388942|0.7083637113692374|Train|
# |0.7077657965437217|0.7941826748794956|0.7801590387594196|0.7072395602684298|0.7073941826799054|0.7077657965437218|Test |
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+

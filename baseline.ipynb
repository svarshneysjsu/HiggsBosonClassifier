# %% [markdown]
# # Baseline for Higgs Boson Detection

# %% [markdown]
# ## Import packages

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.pipeline import PipelineModel, Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import (
    MulticlassClassificationEvaluator,
    BinaryClassificationEvaluator,
)
from pyspark.sql.functions import col, expr, broadcast
from pyspark.ml.functions import vector_to_array
from pyspark.sql import SparkSession
from pyspark import SparkContext
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# ## Create SparkContext and SparkSession

# %%
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/13 18:52:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/05/13 18:52:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
RAW_DATA_FOLDER = "raw_data"
MODELS_FOLDER = "models"
TRAIN = False
SCHEMA = [
    "signal",
    "lepton pT",
    "lepton eta",
    "lepton phi",
    "missing energy magnitude",
    "missing energy phi",
    "jet 1 pt",
    "jet 1 eta",
    "jet 1 phi",
    "jet 1 b-tag",
    "jet 2 pt",
    "jet 2 eta",
    "jet 2 phi",
    "jet 2 b-tag",
    "jet 3 pt",
    "jet 3 eta",
    "jet 3 phi",
    "jet 3 b-tag",
    "jet 4 pt",
    "jet 4 eta",
    "jet 4 phi",
    "jet 4 b-tag",
    "m_jj",
    "m_jjj",
    "m_lv",
    "m_jlv",
    "m_bb",
    "m_wbb",
    "m_wwbb",
]

# %% [markdown]
# ## Read Train CSV, transform and load to Dataframe

# %%
rdd = sc.textFile(os.path.join(RAW_DATA_FOLDER, "HIGGS.csv"))
rdd = rdd.map(
    lambda row: [
        int(float(v)) if i == 0 else float(v) for i, v in enumerate(row.split(","))
    ]
)
df = rdd.toDF(schema=SCHEMA)
train_df, test_df = df.randomSplit([0.7, 0.3], seed=42)

# %% [markdown]
# ## Build Baseline Model
#
# if TRAIN is True, this will train a Baseline Model using train csv
#
# if TRAIN is False, this will load a trained Baseline Model from `models`

# %%
model = None
if TRAIN:
    vector_assembler = VectorAssembler(
        inputCols=[c for c in SCHEMA if c != "signal"], outputCol="features"
    )
    classifier = LogisticRegression(featuresCol="features", labelCol="signal")
    pipeline = Pipeline(stages=[vector_assembler, classifier])
    model = pipeline.fit(train_df)
    model.save(os.path.join(MODELS_FOLDER, "baseline"))
else:
    model = PipelineModel.load(os.path.join(MODELS_FOLDER, "baseline"))
# Out:
# 24/05/13 18:53:09 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 24/05/13 18:53:22 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/05/13 18:53:22 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# 24/05/13 18:53:31 WARN MemoryStore: Not enough space to cache rdd_21_80 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:31 WARN BlockManager: Persisting block rdd_21_80 to disk instead.
# 24/05/13 18:53:41 WARN MemoryStore: Not enough space to cache rdd_21_169 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:41 WARN BlockManager: Persisting block rdd_21_169 to disk instead.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_3 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_4 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_2 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_0 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_6 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_5 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_7 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_11 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_12 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_12 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_10 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_14 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_13 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_21 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_21 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_17 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_23 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_24 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_18 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_24 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_15 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_16 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_19 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_20 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_22 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_27 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_26 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_32 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_32 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_31 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_29 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_34 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_30 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_28 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_34 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_25 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_37 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_37 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_33 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_35 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_36 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_42 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_43 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_39 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_43 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_45 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_41 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_41 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_45 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_46 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_42 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_47 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_40 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_48 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_47 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_48 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_46 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_44 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_51 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_50 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_53 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_49 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_53 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_52 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_51 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_55 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_58 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_57 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_57 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_59 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_56 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_54 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_58 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_56 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_62 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_62 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_61 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_61 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_64 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_60 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_65 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_65 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_64 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_63 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_66 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_68 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_69 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_70 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_67 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_70 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_73 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_72 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_73 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_76 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_75 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_76 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_74 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_75 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_77 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_71 in memory! (computed 7.2 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_79 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_80 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_78 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_79 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_80 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_82 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_82 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_83 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_81 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_83 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_84 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_86 in memory.
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_86 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_85 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:49 WARN MemoryStore: Not enough space to cache rdd_21_87 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_90 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_90 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_92 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_89 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_94 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_91 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_88 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_97 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_93 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_97 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_98 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_95 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_101 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_101 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_99 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_98 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_102 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_102 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_96 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_100 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_103 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_103 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_105 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_106 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_104 in memory! (computed 7.2 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_108 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_109 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_108 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_112 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_111 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_112 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_116 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_107 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_116 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_110 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_114 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_114 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_113 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_115 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_119 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_117 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_121 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_120 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_121 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_118 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_120 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_122 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_124 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_125 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_125 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_126 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_123 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_127 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_128 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_129 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_128 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_130 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_131 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_136 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_135 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_133 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_135 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_132 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_140 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_141 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_134 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_141 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_140 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_138 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_137 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_142 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_138 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_142 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_139 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_145 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_146 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_148 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_145 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_146 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_148 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_149 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_143 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_149 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_147 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_151 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_147 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_152 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_152 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_144 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_151 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_150 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_154 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_154 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_155 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_156 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_158 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_159 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_153 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_158 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_157 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_159 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_161 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_162 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_167 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_166 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_163 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_167 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_166 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_164 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_165 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_160 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_169 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_171 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_169 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_173 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_171 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_170 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_168 in memory! (computed 7.2 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_175 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_172 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_175 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_172 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_174 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_179 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_179 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_182 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_177 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_180 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_178 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_182 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_180 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_178 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_176 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_181 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_3 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_6 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_5 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_3 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_6 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_5 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_2 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_7 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_7 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_4 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_0 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_12 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_11 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_10 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_14 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_18 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_15 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_16 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_13 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_16 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_17 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_15 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_23 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_20 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_23 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_20 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_22 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_22 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_19 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_25 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_25 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_21 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_27 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_26 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_27 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_29 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_24 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_31 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_30 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_33 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_32 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_32 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_33 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_28 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_37 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_35 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_37 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_39 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_39 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_40 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_40 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_36 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_34 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_42 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_42 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_41 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_48 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_47 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_43 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_48 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_45 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_44 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_50 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_44 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_51 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_50 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_51 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_52 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_46 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_52 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_49 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_49 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_56 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_54 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_58 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_57 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_56 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_58 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_57 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_55 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_53 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_59 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_54 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_59 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_60 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_65 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_61 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_65 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_63 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_67 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_64 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_64 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_67 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_69 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_68 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_62 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_66 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_68 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_70 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_78 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_75 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_78 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_74 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_71 in memory! (computed 7.2 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_79 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_79 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_76 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_77 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_76 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_73 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_84 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_84 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_83 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_72 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_83 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_80 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_82 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_81 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_81 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_82 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_89 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_86 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_91 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_86 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_92 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_91 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_89 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_93 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_93 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_85 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_90 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_90 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_92 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_88 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_88 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_94 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_87 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_94 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_96 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_96 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_97 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_97 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_101 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_99 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_101 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_98 in memory.
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_95 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_100 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_102 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_98 in memory! (computed 384.0 B so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_105 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:53:50 WARN MemoryStore: Not enough space to cache rdd_21_104 in memory! (computed 1024.6 KiB so far)
# ...
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_93 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_95 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_91 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_88 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_94 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_97 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_98 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_96 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_98 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_99 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_100 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_105 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_104 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_103 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_102 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_105 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_104 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_101 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_108 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_108 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_111 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_111 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_109 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_110 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_106 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_113 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_112 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_107 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_106 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_113 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_112 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_107 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_114 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_115 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_119 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_117 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_117 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_119 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_118 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_121 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_116 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_124 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_124 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_122 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_123 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_120 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_129 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_127 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_129 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_126 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_127 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_130 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_125 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_130 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_128 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_128 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_134 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_136 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_133 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_136 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_134 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_135 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_131 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_135 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_132 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_139 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_139 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_138 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_137 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_141 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_141 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_146 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_140 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_146 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_142 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_144 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_144 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_145 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_150 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_143 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_150 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_143 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_147 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_149 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_152 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_155 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_156 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_148 in memory! (computed 7.2 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_151 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_154 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_156 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_151 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_153 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_163 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_160 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_161 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_160 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_161 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_165 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_162 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_165 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_162 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_158 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_157 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_158 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_163 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_159 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_166 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_164 in memory! (computed 1024.6 KiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_169 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_169 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_167 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_172 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_172 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_173 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_173 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_170 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_170 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_171 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_168 in memory! (computed 7.2 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_178 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_178 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_175 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_174 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_180 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_179 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_174 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_180 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_179 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_182 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_21_177 in memory.
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_177 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_182 in memory! (computed 384.0 B so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_176 in memory! (computed 7.1 MiB so far)
# 24/05/13 18:54:04 WARN MemoryStore: Not enough space to cache rdd_21_181 in memory! (computed 7.1 MiB so far)

# %% [markdown]
# ## Build Binary Classification Evaluators and Visualizers

# %%
evaluators = {
    "accuracy": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="accuracy"
    ),
    "precision": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="weightedPrecision"
    ),
    "recall": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="weightedRecall"
    ),
    "f1": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="f1"
    ),
    "areaUnderROC": BinaryClassificationEvaluator(
        labelCol="signal", rawPredictionCol="rawPrediction", metricName="areaUnderROC"
    ),
    "areaUnderPR": BinaryClassificationEvaluator(
        labelCol="signal", rawPredictionCol="rawPrediction", metricName="areaUnderPR"
    ),
}
metrics = []

# %%
def evaluate(predictions, split):
    accuracy = evaluators["accuracy"].evaluate(predictions)
    precision = evaluators["precision"].evaluate(predictions)
    recall = evaluators["recall"].evaluate(predictions)
    f1 = evaluators["f1"].evaluate(predictions)
    auc_roc = evaluators["areaUnderROC"].evaluate(predictions)
    auc_pr = evaluators["areaUnderPR"].evaluate(predictions)
    return {
        "Split": split,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "AreaUnderROC": auc_roc,
        "AreaUnderPR": auc_pr,
    }

# %%
def plot_confusion_matrix(predictions, split, ax):
    TP = predictions.filter(
        (predictions.prediction == 1) & (predictions.signal == 1)
    ).count()
    TN = predictions.filter(
        (predictions.prediction == 0) & (predictions.signal == 0)
    ).count()
    FP = predictions.filter(
        (predictions.prediction == 1) & (predictions.signal == 0)
    ).count()
    FN = predictions.filter(
        (predictions.prediction == 0) & (predictions.signal == 1)
    ).count()
    confusion_matrix = [[TP, FP], [FN, TN]]
    _ = sns.heatmap(
        confusion_matrix,
        annot=True,
        fmt="d",
        cmap="Blues",
        square=True,
        cbar=False,
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix for {split}")
    ax.set_ylabel("True Label")
    ax.set_xlabel("Predicted Label")

# %%
def plot_precision_recall_curve(predictions, split, ax):
    slim_preds = predictions.select(["signal", "probability", "prediction"]).withColumn(
        "probability_array", vector_to_array("probability")
    )
    # Create a DataFrame of threshold values
    thresholds = np.linspace(0, 1, num=100)
    threshold_df = spark.createDataFrame(
        [(float(t),) for t in thresholds], ["threshold"]
    )
    cross_joined = slim_preds.crossJoin(broadcast(threshold_df))
    # Define the conditions for TP, FP, TN, FN
    metrics_df = (
        cross_joined.withColumn(
            "Metric",
            expr(
                "CASE "
                + " WHEN probability_array[1] >= threshold AND signal = 1 THEN 'TP' "
                + " WHEN probability_array[1] >= threshold AND signal = 0 THEN 'FP' "
                + " WHEN probability_array[1] < threshold AND signal = 1 THEN 'FN' "
                + " ELSE 'TN' END"
            ),
        )
        .groupBy("threshold")
        .pivot("Metric")
        .count()
    )
    # Calculate precision and recall
    result_df = metrics_df.withColumn(
        "Precision", col("TP") / (col("TP") + col("FP"))
    ).withColumn("Recall", col("TP") / (col("TP") + col("FN")))
    # Collect results for plotting if necessary
    result_data = (
        result_df.select("threshold", "Precision", "Recall")
        .orderBy("threshold")
        .collect()
    )
    # Plotting
    precisions = [
        row["Precision"] for row in result_data if row["Precision"] is not None
    ]
    recalls = [row["Recall"] for row in result_data if row["Recall"] is not None]
    # Filter out None values and ensure that both precision and recall are present
    filtered_data = [
        (row["Precision"], row["Recall"])
        for row in result_data
        if row["Precision"] is not None and row["Recall"] is not None
    ]
    # x[1] is the recall
    sorted_data = sorted(filtered_data, key=lambda x: x[1])
    # Unpack the sorted data
    precisions, recalls = zip(*sorted_data)
    average_precision = 0.0
    for i in range(1, len(precisions)):
        average_precision += (recalls[i] - recalls[i - 1]) * precisions[i]
    # Plotting
    ax.plot(recalls, precisions, color="tab:blue", alpha=0.7)
    ax.fill_between(recalls, precisions, color="tab:blue", alpha=0.2)
    ax.set_title(f"Precision-Recall Curve for {split} (AP={average_precision:.4f})")
    ax.set_ylabel("Precision")
    ax.set_xlabel("Recall")
    ax.set_ylim([0.0, 1.0])
    ax.set_xlim([0.0, 1.0])

# %%
def plot_roc_curve(predictions, split, ax):
    slim_preds = predictions.select(["signal", "probability", "prediction"]).withColumn(
        "probability_array", vector_to_array("probability")
    )
    # Create a DataFrame of threshold values
    thresholds = np.linspace(0, 1, num=100)
    threshold_df = spark.createDataFrame(
        [(float(t),) for t in thresholds], ["threshold"]
    )
    cross_joined = slim_preds.crossJoin(broadcast(threshold_df))
    # Define the conditions for TP, FP, TN, FN
    metrics_df = (
        cross_joined.withColumn(
            "Metric",
            expr(
                "CASE "
                + " WHEN probability_array[1] >= threshold AND signal = 1 THEN 'TP' "
                + " WHEN probability_array[1] >= threshold AND signal = 0 THEN 'FP' "
                + " WHEN probability_array[1] < threshold AND signal = 1 THEN 'FN' "
                + " ELSE 'TN' END"
            ),
        )
        .groupBy("threshold")
        .pivot("Metric")
        .count()
    )
    metrics_summed = metrics_df.groupBy("threshold").sum("TP", "FP", "TN", "FN")
    # Calculate TPR and FPR
    result_df = metrics_summed.withColumn(
        "FPR", col("sum(FP)") / (col("sum(FP)") + col("sum(TN)"))
    ).withColumn("TPR", col("sum(TP)") / (col("sum(TP)") + col("sum(FN)")))
    # Collect results to the driver
    result_data = (
        result_df.select("threshold", "FPR", "TPR").orderBy("threshold").collect()
    )
    # Filter out None values from the results
    filtered_data = [
        row for row in result_data if row["FPR"] is not None and row["TPR"] is not None
    ]
    # Sort by FPR
    sorted_data = sorted(filtered_data, key=lambda x: x["FPR"])
    fprs = [row["FPR"] for row in sorted_data]
    tprs = [row["TPR"] for row in sorted_data]
    # Calculate AUC using the trapezoidal rule
    roc_auc = np.trapz(tprs, fprs)
    # Plotting
    ax.plot(
        fprs, tprs, color="tab:orange", lw=2, label=f"ROC Curve (Area={roc_auc:.4f})"
    )
    ax.plot([0, 1], [0, 1], color="tab:blue", lw=2, linestyle="--")
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")
    ax.set_title(f"Receiver Operating Characteristic for {split}")
    ax.legend(loc="lower right")
    ax.set_ylim([0.0, 1.0])
    ax.set_xlim([0.0, 1.0])

# %% [markdown]
# ## Predictions and Metrics for Train split

# %%
train_predictions = model.transform(train_df)

# %%
metrics.append(evaluate(predictions=train_predictions, split="Train"))

# %%
# fig, ax = plt.subplots(1, 1, figsize=(8, 6))
# plot_confusion_matrix(train_predictions, "Train", ax)

# %%
# fig, ax = plt.subplots(1, 1, figsize=(6, 6))
# plot_roc_curve(train_predictions, "Train", ax)

# %%
# fig, ax = plt.subplots(1, 1, figsize=(6, 6))
# plot_precision_recall_curve(train_predictions, "Train", ax)

# %% [markdown]
# ## Predictions and Metrics for Test split

# %%
test_predictions = model.transform(test_df)

# %%
metrics.append(evaluate(predictions=test_predictions, split="Test"))

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
plot_confusion_matrix(test_predictions, "Test", ax)
# Out:
# 24/05/13 19:00:18 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
plot_roc_curve(test_predictions, "Test", ax)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
plot_precision_recall_curve(test_predictions, "Test", ax)

# %% [markdown]
# ## Print Metrics

# %%
spark.createDataFrame(metrics).show(truncate=False)
# Out:
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+
# |Accuracy          |AreaUnderPR       |AreaUnderROC      |F1                |Precision         |Recall            |Split|
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+
# |0.6415177673392736|0.6836518869673811|0.684395326513634 |0.6369952170824575|0.6420154345092818|0.6415177673392736|Train|
# |0.6421895205661912|0.6841948494259477|0.6848307684402213|0.6377242295910832|0.6426153885354211|0.6421895205661912|Test |
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+

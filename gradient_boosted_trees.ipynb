# %% [markdown]
# # Gradient Boosted Trees for Higgs Boson Detection

# %% [markdown]
# ## Import packages

# %%
from pyspark.ml.pipeline import PipelineModel, Pipeline
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import (
    MulticlassClassificationEvaluator,
    BinaryClassificationEvaluator,
)
from pyspark.sql.functions import col, expr, broadcast
from pyspark.ml.functions import vector_to_array
from pyspark.sql import SparkSession
from pyspark import SparkContext
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# ## Create SparkContext and SparkSession

# %%
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/13 02:18:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
CLEAN_DATA_FOLDER = "clean_data"
MODELS_FOLDER = "models"
TRAIN = True
SCHEMA = [
    "signal",
    "lepton pT",
    "lepton eta",
    "lepton phi",
    "missing energy magnitude",
    "missing energy phi",
    "jet 1 pt",
    "jet 1 eta",
    "jet 1 phi",
    "jet 1 b-tag",
    "jet 2 pt",
    "jet 2 eta",
    "jet 2 phi",
    "jet 2 b-tag",
    "jet 3 pt",
    "jet 3 eta",
    "jet 3 phi",
    "jet 3 b-tag",
    "jet 4 pt",
    "jet 4 eta",
    "jet 4 phi",
    "jet 4 b-tag",
    "m_jj",
    "m_jjj",
    "m_lv",
    "m_jlv",
    "m_bb",
    "m_wbb",
    "m_wwbb",
]

# %% [markdown]
# ## Read Train CSV, transform and load to Dataframe

# %%
rdd = sc.textFile(os.path.join(CLEAN_DATA_FOLDER, "train.csv"))
rdd = rdd.map(
    lambda row: [
        int(float(v)) if i == 0 else float(v) for i, v in enumerate(row.split(","))
    ]
)
train_df = rdd.toDF(schema=SCHEMA)

# %% [markdown]
# ## Build Gradient Boosted Trees Model
#
# if TRAIN is True, this will train a Gradient Boosted Trees Pipeline Model using train csv
#
# if TRAIN is False, this will load a trained Gradient Boosted Trees Pipeline Model from `models`

# %%
model = None
if TRAIN:
    vector_assembler = VectorAssembler(
        inputCols=[c for c in SCHEMA if c != "signal"], outputCol="features"
    )
    classifier = GBTClassifier(featuresCol="features", labelCol="signal", maxIter=20, maxDepth=10)
    pipeline = Pipeline(stages=[vector_assembler, classifier])
    model = pipeline.fit(train_df)
    model.save(os.path.join(MODELS_FOLDER, "gradientBoostedTrees"))
else:
    model = PipelineModel.load(os.path.join(MODELS_FOLDER, "gradientBoostedTrees"))
# Out:
# 24/05/13 02:18:42 WARN PythonRunner: Detected deadlock while completing task 0.0 in stage 1 (TID 1): Attempting to kill Python Worker
# 24/05/13 02:18:47 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_48 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_48 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_47 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_44 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_47 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_45 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_45 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_46 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_46 to disk instead.
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_44 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_42 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_42 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_41 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_41 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_49 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_49 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_40 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_40 to disk instead.
# 24/05/13 02:19:15 WARN MemoryStore: Not enough space to cache rdd_23_43 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:15 WARN BlockManager: Persisting block rdd_23_43 to disk instead.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_49 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_42 in memory.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_42 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_49 in memory.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_49 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_45 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_44 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_40 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_44 in memory.
# 24/05/13 02:19:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_40 in memory.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_40 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_44 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_48 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_43 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_43 in memory.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_45 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_42 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_43 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_41 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_46 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_46 in memory.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_46 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_57 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_58 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:16 WARN BlockManager: Persisting block rdd_23_57 to disk instead.
# 24/05/13 02:19:16 WARN BlockManager: Persisting block rdd_23_58 to disk instead.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_53 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:16 WARN BlockManager: Persisting block rdd_23_53 to disk instead.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_54 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:16 WARN BlockManager: Persisting block rdd_23_54 to disk instead.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_56 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:16 WARN BlockManager: Persisting block rdd_23_56 to disk instead.
# 24/05/13 02:19:16 WARN MemoryStore: Not enough space to cache rdd_23_55 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:16 WARN BlockManager: Persisting block rdd_23_55 to disk instead.
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_50 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:17 WARN BlockManager: Persisting block rdd_23_50 to disk instead.
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_51 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:17 WARN BlockManager: Persisting block rdd_23_51 to disk instead.
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_52 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:17 WARN BlockManager: Persisting block rdd_23_52 to disk instead.
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_59 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:17 WARN BlockManager: Persisting block rdd_23_59 to disk instead.
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_50 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_53 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:17 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_52 in memory.
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_52 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:17 WARN MemoryStore: Not enough space to cache rdd_23_53 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_56 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_56 in memory.
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_56 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_54 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_52 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_54 in memory.
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_54 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_55 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_59 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_60 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:18 WARN BlockManager: Persisting block rdd_23_60 to disk instead.
# 24/05/13 02:19:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_59 in memory.
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_59 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_55 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_61 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:18 WARN BlockManager: Persisting block rdd_23_61 to disk instead.
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_64 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:18 WARN BlockManager: Persisting block rdd_23_64 to disk instead.
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_62 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:18 WARN BlockManager: Persisting block rdd_23_62 to disk instead.
# 24/05/13 02:19:18 WARN MemoryStore: Not enough space to cache rdd_23_68 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:18 WARN BlockManager: Persisting block rdd_23_68 to disk instead.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_66 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:19 WARN BlockManager: Persisting block rdd_23_66 to disk instead.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_65 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:19 WARN BlockManager: Persisting block rdd_23_65 to disk instead.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_69 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_61 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:19 WARN BlockManager: Persisting block rdd_23_69 to disk instead.
# 24/05/13 02:19:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_61 in memory.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_61 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_60 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_66 in memory.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_66 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_66 in memory.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_66 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_68 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_68 in memory.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_68 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_64 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_64 in memory.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_64 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_62 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_62 in memory.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_62 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_73 in memory.
# 24/05/13 02:19:19 WARN MemoryStore: Not enough space to cache rdd_23_73 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:19 WARN BlockManager: Persisting block rdd_23_73 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_72 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_72 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_71 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_71 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_70 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_76 in memory.
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_70 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_76 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_76 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_78 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_78 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_77 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_77 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_71 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_79 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_79 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_74 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:20 WARN BlockManager: Persisting block rdd_23_74 to disk instead.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_72 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_72 in memory.
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_72 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_70 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_73 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_71 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:20 WARN MemoryStore: Not enough space to cache rdd_23_70 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_81 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_78 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_77 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_83 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_76 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_80 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_78 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_78 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_77 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_77 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_83 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_80 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_81 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN BlockManager: Persisting block rdd_23_81 to disk instead.
# 24/05/13 02:19:21 WARN BlockManager: Persisting block rdd_23_80 to disk instead.
# 24/05/13 02:19:21 WARN BlockManager: Persisting block rdd_23_83 to disk instead.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_79 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_79 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_79 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_88 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_89 in memory.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_89 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN BlockManager: Persisting block rdd_23_89 to disk instead.
# 24/05/13 02:19:21 WARN MemoryStore: Not enough space to cache rdd_23_88 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:21 WARN BlockManager: Persisting block rdd_23_88 to disk instead.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_87 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:22 WARN BlockManager: Persisting block rdd_23_87 to disk instead.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_82 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:22 WARN BlockManager: Persisting block rdd_23_82 to disk instead.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:22 WARN BlockManager: Persisting block rdd_23_85 to disk instead.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_86 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:22 WARN BlockManager: Persisting block rdd_23_86 to disk instead.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_82 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_82 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_82 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_80 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_82 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_85 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_81 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_83 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_83 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_83 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_81 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_81 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_87 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_94 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_89 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_93 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_95 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_88 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_89 in memory.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_89 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_93 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_94 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_95 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:22 WARN BlockManager: Persisting block rdd_23_95 to disk instead.
# 24/05/13 02:19:22 WARN BlockManager: Persisting block rdd_23_94 to disk instead.
# 24/05/13 02:19:22 WARN BlockManager: Persisting block rdd_23_93 to disk instead.
# 24/05/13 02:19:22 WARN MemoryStore: Not enough space to cache rdd_23_87 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:23 WARN MemoryStore: Not enough space to cache rdd_23_91 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:23 WARN BlockManager: Persisting block rdd_23_91 to disk instead.
# 24/05/13 02:19:23 WARN MemoryStore: Not enough space to cache rdd_23_88 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:23 WARN MemoryStore: Not enough space to cache rdd_23_99 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:23 WARN BlockManager: Persisting block rdd_23_99 to disk instead.
# 24/05/13 02:19:23 WARN MemoryStore: Not enough space to cache rdd_23_98 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:23 WARN BlockManager: Persisting block rdd_23_98 to disk instead.
# 24/05/13 02:19:23 WARN MemoryStore: Not enough space to cache rdd_23_100 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:23 WARN BlockManager: Persisting block rdd_23_100 to disk instead.
# 24/05/13 02:19:23 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_95 in memory.
# 24/05/13 02:19:23 WARN MemoryStore: Not enough space to cache rdd_23_95 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:23 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_95 in memory.
# 24/05/13 02:19:23 WARN MemoryStore: Not enough space to cache rdd_23_95 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_94 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_93 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_93 in memory.
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_93 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_94 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_91 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_91 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_100 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_103 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_102 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:24 WARN BlockManager: Persisting block rdd_23_102 to disk instead.
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_99 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_99 in memory.
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_99 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:24 WARN BlockManager: Persisting block rdd_23_103 to disk instead.
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_98 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_100 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_107 in memory.
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_107 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:24 WARN BlockManager: Persisting block rdd_23_107 to disk instead.
# 24/05/13 02:19:24 WARN MemoryStore: Not enough space to cache rdd_23_106 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:24 WARN BlockManager: Persisting block rdd_23_106 to disk instead.
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_105 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:25 WARN BlockManager: Persisting block rdd_23_105 to disk instead.
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_104 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:25 WARN BlockManager: Persisting block rdd_23_104 to disk instead.
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_108 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:25 WARN BlockManager: Persisting block rdd_23_108 to disk instead.
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_109 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:25 WARN BlockManager: Persisting block rdd_23_109 to disk instead.
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_103 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_102 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_111 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:25 WARN BlockManager: Persisting block rdd_23_111 to disk instead.
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_103 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_107 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_105 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_102 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_105 in memory.
# 24/05/13 02:19:25 WARN MemoryStore: Not enough space to cache rdd_23_105 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_106 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_104 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_110 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_108 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:26 WARN BlockManager: Persisting block rdd_23_110 to disk instead.
# 24/05/13 02:19:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_106 in memory.
# 24/05/13 02:19:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_108 in memory.
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_108 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_106 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_104 in memory.
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_104 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_109 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_111 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_115 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:26 WARN BlockManager: Persisting block rdd_23_115 to disk instead.
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_112 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:26 WARN BlockManager: Persisting block rdd_23_112 to disk instead.
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_113 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:26 WARN BlockManager: Persisting block rdd_23_113 to disk instead.
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_111 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_112 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_112 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:26 WARN MemoryStore: Not enough space to cache rdd_23_113 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_3 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_4 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_8 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_2 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_5 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_7 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_0 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_1 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_9 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_6 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_11 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_13 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_14 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_16 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_15 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_17 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_20 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_23 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:27 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_26 in memory.
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_26 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:27 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_27 in memory.
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_27 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:27 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_30 in memory.
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_30 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:27 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_31 in memory.
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_31 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:27 WARN MemoryStore: Not enough space to cache rdd_23_24 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_29 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_35 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_37 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_36 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_33 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_38 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_43 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_39 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_40 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_41 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_50 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_47 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_48 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_49 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_54 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_56 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_59 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_57 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_61 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_62 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_64 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_65 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_71 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_70 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_72 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_79 in memory.
# 24/05/13 02:19:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_78 in memory.
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_79 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_78 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_77 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:28 WARN MemoryStore: Not enough space to cache rdd_23_76 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_83 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_87 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_89 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_86 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_88 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_91 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_96 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_94 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_93 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_100 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_101 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_98 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_95 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_104 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_106 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_103 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_105 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_109 in memory.
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_109 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_102 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_108 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_112 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_111 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_8 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_5 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_1 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_0 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_2 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_9 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_12 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_10 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_15 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_18 in memory.
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_18 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_19 in memory.
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_19 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_16 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_13 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_20 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:29 WARN MemoryStore: Not enough space to cache rdd_23_21 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_24 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_31 in memory.
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_27 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_26 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_31 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_30 in memory.
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_23 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_30 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_22 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_25 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_33 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_36 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_38 in memory.
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_38 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_35 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_41 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_39 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_40 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_48 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_46 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_42 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_47 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_53 in memory.
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_53 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_45 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_43 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_50 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_54 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_56 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_57 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_59 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_64 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_66 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_65 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_70 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_81 in memory.
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_81 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_80 in memory.
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_80 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_78 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_77 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_82 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_83 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_89 in memory.
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_89 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:30 WARN MemoryStore: Not enough space to cache rdd_23_87 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_86 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_90 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_88 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_93 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_97 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_94 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_98 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_102 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_99 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_103 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:19:31 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_111 in memory.
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_111 in memory! (computed 384.0 B so far)
# 24/05/13 02:19:31 WARN MemoryStore: Not enough space to cache rdd_23_105 in memory! (computed 5.7 MiB so far)
# ...
# 24/05/13 02:32:44 WARN MemoryStore: Not enough space to cache rdd_23_42 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:44 WARN MemoryStore: Not enough space to cache rdd_23_49 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_55 in memory.
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_55 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:45 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_56 in memory.
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_56 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_61 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_59 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_63 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_67 in memory.
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_67 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_72 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_74 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_73 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_77 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:45 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_76 in memory.
# 24/05/13 02:32:45 WARN MemoryStore: Not enough space to cache rdd_23_76 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_79 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_82 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_80 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_81 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_83 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_86 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_94 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_92 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_93 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_97 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_99 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:46 WARN MemoryStore: Not enough space to cache rdd_23_100 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_107 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_106 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_110 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_109 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_108 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:47 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_3 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_9 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_1 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_0 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_8 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_6 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_5 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:47 WARN MemoryStore: Not enough space to cache rdd_23_2 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_16 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_11 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_14 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_19 in memory.
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_19 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_18 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_23 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_22 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_28 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_29 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_26 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_25 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_33 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:48 WARN MemoryStore: Not enough space to cache rdd_23_32 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_40 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_44 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_46 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_47 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_48 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_55 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_56 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_57 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:49 WARN MemoryStore: Not enough space to cache rdd_23_60 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_63 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_64 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_66 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_70 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_76 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_73 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_72 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_78 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_83 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:50 WARN MemoryStore: Not enough space to cache rdd_23_86 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_87 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_89 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_88 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_90 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_93 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_95 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_98 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_100 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_104 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_107 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_110 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:51 WARN MemoryStore: Not enough space to cache rdd_23_103 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:52 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 24/05/13 02:32:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_7 in memory.
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_7 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_9 in memory.
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_9 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_6 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_8 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_4 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_3 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_1 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:52 WARN MemoryStore: Not enough space to cache rdd_23_11 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_12 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_18 in memory! (computed 1026.9 KiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_16 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_14 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_15 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_19 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_26 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_20 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_27 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_29 in memory.
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_29 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_25 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_28 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_32 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_37 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_38 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:53 WARN MemoryStore: Not enough space to cache rdd_23_36 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:54 WARN MemoryStore: Not enough space to cache rdd_23_48 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:54 WARN MemoryStore: Not enough space to cache rdd_23_45 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:54 WARN MemoryStore: Not enough space to cache rdd_23_55 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:54 WARN MemoryStore: Not enough space to cache rdd_23_57 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:55 WARN MemoryStore: Not enough space to cache rdd_23_76 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:55 WARN MemoryStore: Not enough space to cache rdd_23_78 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:55 WARN MemoryStore: Not enough space to cache rdd_23_80 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_86 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_87 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_85 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_23_92 in memory.
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_92 in memory! (computed 384.0 B so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_98 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_102 in memory! (computed 3.4 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_104 in memory! (computed 2.3 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_101 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_103 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:56 WARN MemoryStore: Not enough space to cache rdd_23_105 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:57 WARN MemoryStore: Not enough space to cache rdd_23_112 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:57 WARN MemoryStore: Not enough space to cache rdd_23_114 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:57 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:32:58 WARN MemoryStore: Not enough space to cache rdd_23_9 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:58 WARN MemoryStore: Not enough space to cache rdd_23_3 in memory! (computed 1544.0 KiB so far)
# 24/05/13 02:32:58 WARN MemoryStore: Not enough space to cache rdd_23_7 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:58 WARN MemoryStore: Not enough space to cache rdd_23_6 in memory! (computed 8.6 MiB so far)
# 24/05/13 02:32:58 WARN MemoryStore: Not enough space to cache rdd_23_5 in memory! (computed 5.7 MiB so far)
# 24/05/13 02:32:58 WARN MemoryStore: Not enough space to cache rdd_23_4 in memory! (computed 3.4 MiB so far)

# %% [markdown]
# ## Feature Importance

# %%
importances = model.stages[-1].featureImportances.toArray()
feature_names = model.stages[0].getInputCols()
feature_importances = list(zip(feature_names, importances))
feature_importances = sorted(feature_importances, key=lambda x: x[1], reverse=True)
feature_names, importances = zip(*feature_importances)
_, ax = plt.subplots(1, 1, figsize=(8, 6))
_ = sns.barplot(x=importances, y=feature_names, ax=ax)
ax.set_title("Feature Importance")
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %% [markdown]
# ## Build Binary Classification Evaluators and Visualizers

# %%
evaluators = {
    "accuracy": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="accuracy"
    ),
    "precision": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="weightedPrecision"
    ),
    "recall": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="weightedRecall"
    ),
    "f1": MulticlassClassificationEvaluator(
        labelCol="signal", predictionCol="prediction", metricName="f1"
    ),
    "areaUnderROC": BinaryClassificationEvaluator(
        labelCol="signal", rawPredictionCol="rawPrediction", metricName="areaUnderROC"
    ),
    "areaUnderPR": BinaryClassificationEvaluator(
        labelCol="signal", rawPredictionCol="rawPrediction", metricName="areaUnderPR"
    ),
}
metrics = []

# %%
def evaluate(predictions, split):
    accuracy = evaluators["accuracy"].evaluate(predictions)
    precision = evaluators["precision"].evaluate(predictions)
    recall = evaluators["recall"].evaluate(predictions)
    f1 = evaluators["f1"].evaluate(predictions)
    auc_roc = evaluators["areaUnderROC"].evaluate(predictions)
    auc_pr = evaluators["areaUnderPR"].evaluate(predictions)
    return {
        "Split": split,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "AreaUnderROC": auc_roc,
        "AreaUnderPR": auc_pr,
    }

# %%
def plot_confusion_matrix(predictions, split, ax):
    TP = predictions.filter(
        (predictions.prediction == 1) & (predictions.signal == 1)
    ).count()
    TN = predictions.filter(
        (predictions.prediction == 0) & (predictions.signal == 0)
    ).count()
    FP = predictions.filter(
        (predictions.prediction == 1) & (predictions.signal == 0)
    ).count()
    FN = predictions.filter(
        (predictions.prediction == 0) & (predictions.signal == 1)
    ).count()
    confusion_matrix = [[TP, FP], [FN, TN]]
    _ = sns.heatmap(
        confusion_matrix,
        annot=True,
        fmt="d",
        cmap="Blues",
        square=True,
        cbar=False,
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix for {split}")
    ax.set_ylabel("True Label")
    ax.set_xlabel("Predicted Label")

# %%
def plot_precision_recall_curve(predictions, split, ax):
    slim_preds = predictions.select(["signal", "probability", "prediction"]).withColumn(
        "probability_array", vector_to_array("probability")
    )
    # Create a DataFrame of threshold values
    thresholds = np.linspace(0, 1, num=100)
    threshold_df = spark.createDataFrame(
        [(float(t),) for t in thresholds], ["threshold"]
    )
    cross_joined = slim_preds.crossJoin(broadcast(threshold_df))
    # Define the conditions for TP, FP, TN, FN
    metrics_df = (
        cross_joined.withColumn(
            "Metric",
            expr(
                "CASE "
                + " WHEN probability_array[1] >= threshold AND signal = 1 THEN 'TP' "
                + " WHEN probability_array[1] >= threshold AND signal = 0 THEN 'FP' "
                + " WHEN probability_array[1] < threshold AND signal = 1 THEN 'FN' "
                + " ELSE 'TN' END"
            ),
        )
        .groupBy("threshold")
        .pivot("Metric")
        .count()
    )
    # Calculate precision and recall
    result_df = metrics_df.withColumn(
        "Precision", col("TP") / (col("TP") + col("FP"))
    ).withColumn("Recall", col("TP") / (col("TP") + col("FN")))
    # Collect results for plotting if necessary
    result_data = (
        result_df.select("threshold", "Precision", "Recall")
        .orderBy("threshold")
        .collect()
    )
    # Plotting
    precisions = [
        row["Precision"] for row in result_data if row["Precision"] is not None
    ]
    recalls = [row["Recall"] for row in result_data if row["Recall"] is not None]
    # Filter out None values and ensure that both precision and recall are present
    filtered_data = [
        (row["Precision"], row["Recall"])
        for row in result_data
        if row["Precision"] is not None and row["Recall"] is not None
    ]
    # x[1] is the recall
    sorted_data = sorted(filtered_data, key=lambda x: x[1])
    # Unpack the sorted data
    precisions, recalls = zip(*sorted_data)
    average_precision = 0.0
    for i in range(1, len(precisions)):
        average_precision += (recalls[i] - recalls[i - 1]) * precisions[i]
    # Plotting
    ax.plot(recalls, precisions, color="tab:blue", alpha=0.7)
    ax.fill_between(recalls, precisions, color="tab:blue", alpha=0.2)
    ax.set_title(f"Precision-Recall Curve for {split} (AP={average_precision:.4f})")
    ax.set_ylabel("Precision")
    ax.set_xlabel("Recall")
    ax.set_ylim([0.0, 1.0])
    ax.set_xlim([0.0, 1.0])

# %%
def plot_roc_curve(predictions, split, ax):
    slim_preds = predictions.select(["signal", "probability", "prediction"]).withColumn(
        "probability_array", vector_to_array("probability")
    )
    # Create a DataFrame of threshold values
    thresholds = np.linspace(0, 1, num=100)
    threshold_df = spark.createDataFrame(
        [(float(t),) for t in thresholds], ["threshold"]
    )
    cross_joined = slim_preds.crossJoin(broadcast(threshold_df))
    # Define the conditions for TP, FP, TN, FN
    metrics_df = (
        cross_joined.withColumn(
            "Metric",
            expr(
                "CASE "
                + " WHEN probability_array[1] >= threshold AND signal = 1 THEN 'TP' "
                + " WHEN probability_array[1] >= threshold AND signal = 0 THEN 'FP' "
                + " WHEN probability_array[1] < threshold AND signal = 1 THEN 'FN' "
                + " ELSE 'TN' END"
            ),
        )
        .groupBy("threshold")
        .pivot("Metric")
        .count()
    )
    metrics_summed = metrics_df.groupBy("threshold").sum("TP", "FP", "TN", "FN")
    # Calculate TPR and FPR
    result_df = metrics_summed.withColumn(
        "FPR", col("sum(FP)") / (col("sum(FP)") + col("sum(TN)"))
    ).withColumn("TPR", col("sum(TP)") / (col("sum(TP)") + col("sum(FN)")))
    # Collect results to the driver
    result_data = (
        result_df.select("threshold", "FPR", "TPR").orderBy("threshold").collect()
    )
    # Filter out None values from the results
    filtered_data = [
        row for row in result_data if row["FPR"] is not None and row["TPR"] is not None
    ]
    # Sort by FPR
    sorted_data = sorted(filtered_data, key=lambda x: x["FPR"])
    fprs = [row["FPR"] for row in sorted_data]
    tprs = [row["TPR"] for row in sorted_data]
    # Calculate AUC using the trapezoidal rule
    roc_auc = np.trapz(tprs, fprs)
    # Plotting
    ax.plot(
        fprs, tprs, color="tab:orange", lw=2, label=f"ROC Curve (Area={roc_auc:.4f})"
    )
    ax.plot([0, 1], [0, 1], color="tab:blue", lw=2, linestyle="--")
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")
    ax.set_title(f"Receiver Operating Characteristic for {split}")
    ax.legend(loc="lower right")
    ax.set_ylim([0.0, 1.0])
    ax.set_xlim([0.0, 1.0])

# %% [markdown]
# ## Predictions and Metrics for Train split

# %%
train_predictions = model.transform(train_df)

# %%
metrics.append(evaluate(predictions=train_predictions, split="Train"))
# Out:
# 24/05/13 02:36:29 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:36:29 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/05/13 02:36:29 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# 24/05/13 02:36:50 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:37:09 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:37:29 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:37:48 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:38:19 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB

# %%
# fig, ax = plt.subplots(1, 1, figsize=(8, 6))
# plot_confusion_matrix(train_predictions, "Train", ax)

# %%
# fig, ax = plt.subplots(1, 1, figsize=(6, 6))
# plot_roc_curve(train_predictions, "Train", ax)

# %%
# fig, ax = plt.subplots(1, 1, figsize=(6, 6))
# plot_precision_recall_curve(train_predictions, "Train", ax)

# %% [markdown]
# ## Read Test CSV, transform and load to Dataframe

# %%
rdd = sc.textFile(os.path.join(CLEAN_DATA_FOLDER, "test.csv"))
rdd = rdd.map(
    lambda row: [
        int(float(v)) if i == 0 else float(v) for i, v in enumerate(row.split(","))
    ]
)
test_df = rdd.toDF(schema=SCHEMA)

# %% [markdown]
# ## Predictions and Metrics for Test split

# %%
test_predictions = model.transform(test_df)

# %%
metrics.append(evaluate(predictions=test_predictions, split="Test"))
# Out:
# 24/05/13 02:38:49 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:38:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:39:06 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:39:15 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:39:23 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:39:36 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
plot_confusion_matrix(test_predictions, "Test", ax)
# Out:
# 24/05/13 02:39:49 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/05/13 02:39:49 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 24/05/13 02:39:58 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 24/05/13 02:40:06 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 24/05/13 02:40:14 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
plot_roc_curve(test_predictions, "Test", ax)
# Out:
# 24/05/13 02:40:22 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:41:45 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:41:45 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:41:45 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:41:45 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:43:10 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:43:10 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:43:10 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:43:11 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
plot_precision_recall_curve(test_predictions, "Test", ax)
# Out:
# 24/05/13 02:43:11 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:44:32 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:44:32 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:44:32 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:44:33 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:45:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:45:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:45:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 24/05/13 02:45:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB

# %% [markdown]
# ## Print Metrics

# %%
spark.createDataFrame(metrics).show(truncate=False)
# Out:
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+
# |Accuracy          |AreaUnderPR       |AreaUnderROC      |F1                |Precision         |Recall            |Split|
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+
# |0.7327127706210524|0.829623446610859 |0.8137384188261013|0.7325958426326075|0.7325420990547433|0.7327127706210523|Train|
# |0.7293901788481153|0.8264012154674685|0.810242820925489 |0.7292806999728256|0.7292257129751555|0.7293901788481152|Test |
# +------------------+------------------+------------------+------------------+------------------+------------------+-----+
